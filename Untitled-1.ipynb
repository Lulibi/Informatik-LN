# %% [markdown]
# # Obdachlosigkeit im globalen Vergleich
# Team:
# - Jasleen Bal
# - Luana Birtone
# - Katarina Djuric

# %% [markdown]
# Fragen
#
# - Welche Länder waren im Jahr 2023 am meisten von der Obdachlosigkeit betroffen?
# - Was sind Gründe dafür?

# %% [markdown]
# Quellen
# - https://ourworldindata.org/grapher/homelessness-rate-point-in-time-count

# %% [markdown]
# # 1. Daten beschaffen und laden

# %%
import pandas as pd
from matplotlib import pyplot as plt

# %%
df = pd.read_csv('homelessness-rate-point-in-time-count.csv')
df.head(10)
# Out:
#        Entity Code  Year  \
# 0   Australia  AUS  2021
# 1      Canada  CAN  2022
# 2  Costa Rica  CRI  2023
# 3     Czechia  CZE  2022
# 4     Denmark  DNK  2022
# 5     Finland  FIN  2023
# 6      France  FRA  2022
# 7     Germany  DEU  2022
# 8      Greece  GRC  2023
# 9     Iceland  ISL  2021
#
#    Rate of people experiencing homelessness (point-in-time, ETHOS 1)  \
# 0                                          29.737530
# 1                                          23.891660
# 2                                                NaN
# 3                                          85.877396
# 4                                           9.051570
# 5                                                NaN
# 6                                           8.095070
# 7                                          45.943825
# 8                                                NaN
# 9                                          52.077324
#
# ...
